# %%
import subprocess

# 使用subprocess.run()运行pip install命令安装spacy和pandas
subprocess.run(['pip', 'install', '-U', 'spacy'], check=True)
subprocess.run(['pip', 'install', 'pandas'], check=True)
# Out:
# CompletedProcess(args=['pip', 'install', 'pandas'], returncode=0)

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd 
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
filepath = r"C:\Users\qnj\Desktop\NLP\Little Prince.txt"
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %%
displacy.render(document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chapter 1
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# we are introduced to the narrator, a pilot, and his<br>ideas about grown-ups<br>Once when I was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six years old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  I saw a magnificent picture in a book, called<br>True Stories from
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nature
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , about the primeval forest. It was a picture of a boa<br>constrictor in the act of swallowing an animal. Here is a copy of the drawing.<br>In the book it said: &quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  constrictors swallow their prey whole, without chewing<br>it. After that they are not able to move, and they sleep through
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the six months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>that they need for digestion.&quot;<br>I pondered deeply, then, over the adventures of the jungle. And after some<br>work with a colored pencil I succeeded in making my
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  drawing. My Drawing<br>Number One. It looked like this:<br>I showed my masterpiece to the grown-ups, and asked them whether the<br>drawing frightened them.<br>But they answered: &quot;Frighten? Why should any one be frightened by a hat?&quot;<br>My drawing was not a picture of a hat. It was a picture of a boa constrictor<br>digesting an elephant. But since the grown-ups were not able to understand it,<br>I made another drawing: I drew the inside of the boa constrictor, so that the<br>grown-ups could see it clearly. They always need to have things explained. My<br>Drawing Number Two looked like this:<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br>The grown-ups' response, this time, was to advise me to lay aside my<br>drawings of boa constrictors, whether from the inside or the outside, and<br>devote myself instead to geography, history, arithmetic and grammar. That is<br>why, at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the age of six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I gave up what might have been a magnificent career as<br>a painter. I had been disheartened by the failure of my Drawing Number One<br>and my Drawing Number Two. Grown-ups never understand anything by<br>themselves, and it is tiresome for children to be always and forever explaining<br>things to them.<br>So then I chose another profession, and learned to pilot airplanes. I have flown<br>a little over all parts of the world; and it is true that geography has been very<br>useful to me. At a glance I can distinguish
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arizona
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . If one gets lost<br>in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , such knowledge is valuable.<br>In the course of this life I have had a great many encounters with a great many<br>people who have been concerned with matters of consequence. I have lived a<br>great deal among grown-ups. I have seen them intimately, close at hand. And<br>that hasn't much improved my opinion of them.<br>Whenever I met
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of them who seemed to me at all clear-sighted, I tried the<br>experiment of showing him my Drawing Number One, which I have always<br>kept. I would try to find out, so, if this was a person of true understanding. But,<br>whoever it was, he, or she, would always say:<br>&quot;That is a hat.&quot;<br>Then I would never talk to that person about boa constrictors, or primeval<br>forests, or stars. I would bring myself down to his level. I would talk to him<br>about bridge, and golf, and politics, and neckties. And the grown-up would be<br>greatly pleased to have met such a sensible man.<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chapter 2
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# the narrator crashes in the desert and makes the<br>acquaintance of the little prince<br>So I lived my life alone, without anyone that I could really talk to, until I had an<br>accident with my plane in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Desert of Sahara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six years ago
#     <span style="f

# %%
document.ents
# Out:
# (Chapter 1
#   ,
#  six years old,
#  Nature,
#  Boa,
#  the six months,
#  first,
#  5,
#  the age of six,
#  China,
#  Arizona,
#  the night,
#  one,
#  6,
#  Chapter 2
#   ,
#  the Desert of Sahara,
#  six years ago,
#  The first night,
#  a thousand miles,
#  7,
#  six years old,
#  boas,
#  boas,
#  a thousand
#  miles,
#  a thousand miles,
#  a thousand miles,
#  8,
#  two,
#  9,
#  10,
#  Chapter 3,
#  first,
#  11,
#  night,
#  the day,
#  Anywhere,
#  Straight ahead of him, nobody can go very far,
#  12,
#  Chapter 4,
#  second,
#  Earth,
#  Jupiter,
#  Mars,
#  Venus--,
#  hundreds,
#  13,
#  Asteroid 325,
#  B-612,
#  Turkish,
#  1909,
#  the International
#  Astronomical Congress,
#  Turkish,
#  14,
#  Asteroid B-612,
#  Turkish,
#  European,
#  1920,
#  20,000,
#  Asteroid B-612,
#  15,
#  Six years,
#  six,
#  One,
#  one,
#  16,
#  Chapter 5,
#  each day,
#  the third day,
#  doubt--,
#  one,
#  17,
#  the little prince lived--,
#  planets--,
#  earth,
#  first,
#  one,
#  18,
#  first,
#  one day,
#  some day,
#  another day,
#  three,
#  19,
#  20,
#  Chapter 6,
#  the morning,
#  the fourth day,
#  first,
#  noon,
#  the United States,
#  France,
#  France,
#  one minute,
#  noon,
#  France,
#  One day,
#  forty-four,
#  21,
#  the day,
#  forty-four,
#  22,
#  Chapter 7,
#  fifth,
#  sheep--,
#  sheep--,
#  first,
#  23,
#  first,
#  all day,
#  millions of years,
#  millions of
#  years,
#  one,
#  one,
#  24,
#  some morning,
#  some one,
#  one,
#  millions and millions,
#  one,
#  one,
#  one,
#  Earth,
#  25,
#  Chapter 8,
#  only one,
#  One morning,
#  one day,
#  first,
#  coquettish,
#  days,
#  one morning,
#  26,
#  One day,
#  four,
#  27,
#  drafts--,
#  two,
#  three,
#  28,
#  one day,
#  One,
#  29,
#  Chapter 9,
#  the morning,
#  two,
#  one,
#  One,
#  Volcanic,
#  this last morning,
#  30,
#  I. Try,
#  wind--,
#  two or,
#  butterflies--,
#  caterpillars--,
#  four,
#  31,
#  Chapter 10,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  first,
#  Approach,
#  years,
#  Yawn,
#  Hum,
#  Hum,
#  32,
#  question--,
#  33,
#  forty-four,
#  one day,
#  seventy-two,
#  a hundred,
#  two,
#  hundred,
#  one,
#  one,
#  One,
#  first,
#  34,
#  Hum,
#  Hum,
#  Hum,
#  Hum,
#  about twenty minutes to eight,
#  Justice,
#  one,
#  Hum,
#  Hum,
#  night,
#  35,
#  one minute,
#  36,
#  Chapter 11,
#  second,
#  first,
#  morning,
#  37,
#  five minutes,
#  38,
#  Chapter 12,
#  Ashamed of what,
#  39,
#  40,
#  Chapter 13,
#  fourth,
#  morning,
#  Three,
#  two,
#  five,
#  Five,
#  seven,
#  twelve,
#  Twelve,
#  three,
#  fifteen,
#  Fifteen,
#  seven,
#  twenty-two,
#  Twenty-two,
#  six,
#  twenty-eight,
#  Twenty-six,
#  five,
#  thirty-one,
#  five-hundred-and-one-million,
#  six-hundred-twenty-two-thousand,
#  seven-hundred-thirty-one,
#  Five hundred million,
#  Five-hundred,
#  Two,
#  five,
#  seven,
#  Five-hundred,
#  one million,
#  41,
#  the fifty-four years,
#  only three,
#  first,
#  twenty-two years ago,
#  four,
#  second,
#  eleven years ago,
#  third,
#  five,
#  one,
#  millions--,
#  Millions,
#  Millions,
#  Bees,
#  five-hundred millions,
#  Five-hundred,
#  one million,
#  six-hundred-twenty-two thousand,
#  seven-hundred-thirty-one,
#  42,
#  first,
#  43,
#  three,
#  44,
#  Chapter 14,
#  fifth,
#  one,
#  one,
#  one,
#  evening,
#  45,
#  the old days,
#  the
#  day,
#  year,
#  every minute,
#  second,
#  only one minute,
#  a month,
#  A month,
#  Thirty minutes,
#  Thirty days,
#  evening,
#  other days,
#  46,
#  three,
#  the day,
#  one,
#  only one,
#  two,
#  1440,
#  47,
#  Chapter 15,
#  sixth,
#  ten,
#  48,
#  two,
#  One,
#  one,
#  49,
#  first,
#  One,
#  three,
#  Two,
#  One,
#  Geographies,
#  50,
#  four,
#  first,
#  The planet Earth,
#  51,
#  Chapter 16,
#  Earth,
#  seventh,
#  Earth,
#  Earth,
#  111,
#  Negro,
#  7000,
#  900,000,
#  7,500,000,
#  311,000,000,
#  about 2,000,000,000,
#  Earth,
#  six,
#  462,511,
#  First,
#  New Zealand,
#  Australia,
#  China,
#  Siberia,
#  Russia,
#  Indies,
#  Africa,
#  Europe,
#  South America,
#  South America,
#  North America,
#  the North Pole,
#  South,
#  two,
#  52,
#  Chapter 17,
#  one,
#  Earth,
#  two billion,
#  one public square twenty miles,
#  twenty miles,
#  Pacific,
#  fig,
#  Earth,
#  53,
#  evening,
#  evening,
#  Earth,
#  Africa,
#  Earth,
#  Earth,
#  one,
#  54,
#  Whomever I touch,
#  Earth,
#  some day,
#  55,
#  Chapter 18,
#  one,
#  three,
#  morning,
#  morning,
#  six,
#  seven,
#  several years ago,
#  56,
#  Chapter 19,
#  three,
#  one,
#  morning,
#  morning,
#  57,
#  first,
#  58,
#  Chapter 20,
#  morning,
#  morning,
#  only one,
#  five thousand,
#  one,
#  59,
#  three,
#  knees--,
#  one,
#  60,
#  Chapter 21,
#  fox,
#  morning,
#  morning,
#  fox,
#  61,
#  a hundred thousand,
#  a hundred thousand,
#  Earth,
#  Earth,
#  62,
#  fox,
#  One,
#  one,
#  First,
#  63,
#  The next day,
#  the same hour,
#  four o'clock,
#  three o'clock,
#  four o'clock,
#  hour,
#  one day,
#  other days,
#  one hour,
#  Thursday,
#  vineyards,
#  every other day,
#  the hour,
#  64,
#  first,
#  a hundred thousand,
#  hundreds,
#  two,
#  65,
#  66,
#  Chapter 22,
#  morning,
#  morning,
#  second,
#  third,
#  first,
#  67,
#  68,
#  Chapter 23,
#  morning,
#  morning,
#  fifty-three minutes,
#  fifty-three minutes,
#  fifty-three minutes,
#  69,
#  Chapter 24,
#  eighth,
#  several hours,
#  70,
#  One,
#  Earth,
#  71,
#  72,
#  Chapter 25,
#  Sahara,
#  Sahara,
#  73,
#  the Midnight Mass,
#  five thousand,
#  one,
#  74,
#  You know--,
#  You know--,
#  earth,
#  Tomorrow,
#  One,
#  the morning,
#  first,
#  a thousand miles,
#  75,
#  questions--,
#  one,
#  tomorrow,
#  evening,
#  One,
#  76,
#  Chapter 26,
#  the next evening,
#  the right day,
#  tonight,
#  only twenty metres,
#  77,
#  wall--,
#  just thirty seconds,
#  78,
#  today,
#  Dear little man,
#  this evening,
#  Tonight,
#  a year,
#  Earth,
#  a year ago,
#  79,
#  night,
#  one,
#  one,
#  night,
#  80,
#  second,
#  81,
#  Ah!,
#  one,
#  five hundred million,
#  five hundred million,
#  82,
#  You know--,
#  four,
#  one,
#  83,
#  84,
#  Chapter 27,
#  six years,
#  five hundred million,
#  one,
#  every night,
#  some one evening,
#  85,
#  Earth,
#  some day,
#  African)

# %%
for named_entity in document.ents:
    print(named_entity, named_entity.label_)
# Out:
# Chapter 1
#   LAW
# six years old DATE
# Nature WORK_OF_ART
# Boa PERSON
# the six months DATE
# first ORDINAL
# 5 CARDINAL
# the age of six DATE
# China GPE
# Arizona GPE
# the night TIME
# one CARDINAL
# 6 CARDINAL
# Chapter 2
#   LAW
# the Desert of Sahara GPE
# six years ago DATE
# The first night TIME
# a thousand miles QUANTITY
# 7 CARDINAL
# six years old DATE
# boas ORG
# boas ORG
# a thousand
# miles QUANTITY
# a thousand miles QUANTITY
# a thousand miles QUANTITY
# 8 CARDINAL
# two CARDINAL
# 9 CARDINAL
# 10 CARDINAL
# Chapter 3 LAW
# first ORDINAL
# 11 CARDINAL
# night TIME
# the day DATE
# Anywhere WORK_OF_ART
# Straight ahead of him, nobody can go very far WORK_OF_ART
# 12 CARDINAL
# Chapter 4 LAW
# second ORDINAL
# Earth LOC
# Jupiter LOC
# Mars LOC
# Venus-- ORG
# hundreds CARDINAL
# 13 CARDINAL
# Asteroid 325 PRODUCT
# B-612 PRODUCT
# Turkish NORP
# 1909 DATE
# the International
# Astronomical Congress ORG
# Turkish NORP
# 14 CARDINAL
# Asteroid B-612 PERSON
# Turkish NORP
# European NORP
# 1920 DATE
# 20,000 MONEY
# Asteroid B-612 PERSON
# 15 CARDINAL
# Six years DATE
# six DATE
# One CARDINAL
# one CARDINAL
# 16 CARDINAL
# Chapter 5 LAW
# each day DATE
# the third day DATE
# doubt-- PERSON
# one CARDINAL
# 17 CARDINAL
# the little prince lived-- ORG
# planets-- ORG
# earth LOC
# first ORDINAL
# one CARDINAL
# 18 CARDINAL
# first ORDINAL
# one day DATE
# some day DATE
# another day DATE
# three CARDINAL
# 19 CARDINAL
# 20 CARDINAL
# Chapter 6 LAW
# the morning TIME
# the fourth day DATE
# first ORDINAL
# noon TIME
# the United States GPE
# France GPE
# France GPE
# one minute TIME
# noon TIME
# France GPE
# One day DATE
# forty-four CARDINAL
# 21 CARDINAL
# the day DATE
# forty-four CARDINAL
# 22 CARDINAL
# Chapter 7 LAW
# fifth ORDINAL
# sheep-- PERSON
# sheep-- PERSON
# first ORDINAL
# 23 CARDINAL
# first ORDINAL
# all day DATE
# millions of years DATE
# millions of
# years DATE
# one CARDINAL
# one CARDINAL
# 24 CARDINAL
# some morning TIME
# some one CARDINAL
# one CARDINAL
# millions and millions MONEY
# one CARDINAL
# one CARDINAL
# one CARDINAL
# Earth LOC
# 25 CARDINAL
# Chapter 8 LAW
# only one CARDINAL
# One morning TIME
# one day DATE
# first ORDINAL
# coquettish NORP
# days DATE
# one morning TIME
# 26 CARDINAL
# One day DATE
# four CARDINAL
# 27 CARDINAL
# drafts-- ORG
# two CARDINAL
# three CARDINAL
# 28 CARDINAL
# one day DATE
# One CARDINAL
# 29 CARDINAL
# Chapter 9 LAW
# the morning TIME
# two CARDINAL
# one CARDINAL
# One CARDINAL
# Volcanic ORG
# this last morning TIME
# 30 CARDINAL
# I. Try ORG
# wind-- ORG
# two or CARDINAL
# butterflies-- NORP
# caterpillars-- ORG
# four CARDINAL
# 31 CARDINAL
# Chapter 10 LAW
# 325 CARDINAL
# 326 CARDINAL
# 327 CARDINAL
# 328 CARDINAL
# 329 CARDINAL
# 330 CARDINAL
# first ORDINAL
# Approach PERSON
# years DATE
# Yawn PERSON
# Hum GPE
# Hum GPE
# 32 CARDINAL
# question-- NORP
# 33 CARDINAL
# forty-four CARDINAL
# one day DATE
# seventy-two CARDINAL
# a hundred CARDINAL
# two CARDINAL
# hundred CARDINAL
# one CARDINAL
# one CARDINAL
# One CARDINAL
# first ORDINAL
# 34 CARDINAL
# Hum GPE
# Hum GPE
# Hum GPE
# Hum GPE
# about twenty minutes to eight TIME
# Justice ORG
# one CARDINAL
# Hum GPE
# Hum GPE
# night TIME
# 35 CARDINAL
# one minute TIME
# 36 CARDINAL
# Chapter 11 LAW
# second ORDINAL
# first ORDINAL
# morning TIME
# 37 CARDINAL
# five minutes TIME
# 38 CARDINAL
# Chapter 12 LAW
# Ashamed of what WORK_OF_ART
# 39 CARDINAL
# 40 CARDINAL
# Chapter 13 LAW
# fourth ORDINAL
# morning TIME
# Three CARDINAL
# two CARDINAL
# five CARDINAL
# Five CARDINAL
# seven CARDINAL
# twelve CARDINAL
# Twelve CARDINAL
# three CARDINAL
# fifteen DATE
# Fifteen CARDINAL
# seven CARDINAL
# twenty-two CARDINAL
# Twenty-two CARDINAL
# six CARDINAL
# twenty-eight CARDINAL
# Twenty-six CARDINAL
# five CARDINAL
# thirty-one CARDINAL
# five-hundred-and-one-million CARDINAL
# six-hundred-twenty-two-thousand CARDINAL
# seven-hundred-thirty-one CARDINAL
# Five hundred million CARDINAL
# Five-hundred CARDINAL
# Two CARDINAL
# five CARDINAL
# seven CARDINAL
# Five-hundred CARDINAL
# one million CARDINAL
# 41 CARDINAL
# the fifty-four years DATE
# only three CARDINAL
# first ORDINAL
# twenty-two years ago DATE
# four CARDINAL
# second ORDINAL
# eleven years ago DATE
# third ORDINAL
# five CARDINAL
# one CARDINAL
# millions-- PRODUCT
# Millions CARDINAL
# Millions CARDINAL
# Bees PERSON
# five-hundred millions CARDINAL
# Five-hundred CARDINAL
# one million CARDINAL
# six-hundred-twenty-two thousand CARDINAL
# seven-hundred-thirty-one CARDINAL
# 42 CARDINAL
# first ORDINAL
# 43 CARDINAL
# three CARDINAL
# 44 CARDINAL
# Chapter 14 LAW
# fifth ORDINAL
# one CARDINAL
# one CARDINAL
# one CARDINAL
# evening TIME
# 45 CARDINAL
# the old days DATE
# the
# day DATE
# year DATE
# every minute TIME
# second ORDINAL
# only one minute TIME
# a month DATE
# A month DATE
# Thirty minutes TIME
# Thirty days DATE
# evening TIME
# other days DATE
# 46 CARDINAL
# three CARDINAL
# the day DATE
# one CARDINAL
# only one CARDINAL
# two CARDINAL
# 1440 CARDINAL
# 47 CARDINAL
# Chapter 15 LAW
# sixth ORDINAL
# ten CARDINAL
# 48 CARDINAL
# two CARDINAL
# One CARDINAL
# one CARDINAL
# 49 CARDINAL
# first ORDINAL
# One CARDINAL
# three CARDINAL
# Two CARDINAL
# One CARDINAL
# Geographies WORK_OF_ART
# 50 CARDINAL
# four CARDINAL
# first ORDINAL
# The planet Earth WORK_OF_ART
# 51 CARDINAL
# Chapter 16 LAW
# Earth LOC
# seventh ORDINAL
# Earth LOC
# Earth LOC
# 111 CARDINAL
# Negro ORG
# 7000 CARDINAL
# 900,000 CARDINAL
# 7,500,000 CARDINAL
# 311,000,000 CARDINAL
# about 2,000,000,000 CARDINAL
# Earth LOC
# six CARDINAL
# 462,511 CARDINAL
# First ORDINAL
# New Zealand GPE
# Australia GPE
# China GPE
# Siberia LOC
# Russia GPE
# Indies ORG
# Africa LOC
# Europe LOC
# South America LOC
# South America LOC
# North America LOC
# the North Pole LOC
# South LOC
# two CARDINAL
# 52 CARDINAL
# Chapter 17 LAW
# one CARDINAL
# Earth LOC
# two billion CARDINAL
# one public square twenty miles QUANTITY
# twenty miles QUANTITY
# Pacific LOC
# fig ORG
# Earth LOC
# 53 CARDINAL
# evening TIME
# evening TIME
# Earth LOC
# Africa LOC
# Earth LOC
# Earth LOC
# one CARDINAL
# 54 CARDINAL
# Whomever I touch WORK_OF_ART
# Earth LOC
# some day DATE
# 55 CARDINAL
# Chapter 18 LAW
# one CARDINAL
# three CARDINAL
# morning TIME
# morning TIME
# six CARDINAL
# seven CARDINAL
# several years ago DATE
# 56 CARDINAL
# Chapter 19 LAW
# three CARDINAL
# one CARDINAL
# morning TIME
# morning TIME
# 57 CARDINAL
# first ORDINAL
# 58 CARDINAL
# Chapter 20 LAW
# morning TIME
# morning TIME
# only one CARDINAL
# five thousand CARDINAL
# one CARDINAL
# 59 CARDINAL
# three CARDINAL
# knees-- ORG
# one CARDINAL
# 60 CARDINAL
# Chapter 21 LAW
# fox ORG
# morning TIME
# morning TIME
# fox ORG
# 61 CARDINAL
# a hundred thousand CARDINAL
# a hundred thousand CARDINAL
# Earth LOC
# Earth LOC
# 62 CARDINAL
# fox ORG
# One CARDINAL
# one CARDINAL
# First ORDINAL
# 63 CARDINAL
# The next day DATE
# the same hour TIME
# four o'clock TIME
# three o'clock TIME
# four o'clock TIME
# hour TIME
# one day DATE
# other days DATE
# one hour TIME
# Thursday DATE
# vineyards LOC
# every other day DATE
# the hour TIME
# 64 CARDINAL
# first ORDINAL
# a hundred thousand CARDINAL
# hundreds CARDINAL
# two CARDINAL
# 65 CARDINAL
# 66 CARDINAL
# Chapter 22 LAW
# morning TIME
# morning TIME
# second ORDINAL
# third ORDINAL
# first ORDINAL
# 67 CARDINAL
# 68 CARDINAL
# Chapter 23 LAW
# morning TIME
# morning TIME
# fifty-three minutes TIME
# fifty-three minutes TIME
# fifty-three minutes TIME
# 69 CARDINAL
# Chapter 24 LAW
# eighth ORDINAL
# several hours TIME
# 70 CARDINAL
# One CARDINAL
# Earth LOC
# 71 CARDINAL
# 72 CARDINAL
# Chapter 25 LAW
# Sahara LOC
# Sahara LOC
# 73 CARDINAL
# the Midnight Mass WORK_OF_ART
# five thousand CARDINAL
# one CARDINAL
# 74 CARDINAL
# You know-- WORK_OF_ART
# You know-- WORK_OF_ART
# earth LOC
# Tomorrow DATE
# One CARDINAL
# the morning TIME
# first ORDINAL
# a thousand miles QUANTITY
# 75 CARDINAL
# questions-- ORG
# one CARDINAL
# tomorrow DATE
# evening TIME
# One CARDINAL
# 76 CARDINAL
# Chapter 26 LAW
# the next evening TIME
# the right day DATE
# tonight TIME
# only twenty metres QUANTITY
# 77 CARDINAL
# wall-- ORG
# just thirty seconds TIME
# 78 CARDINAL
# today DATE
# Dear little man WORK_OF_ART
# this evening TIME
# Tonight TIME
# a year DATE
# Earth LOC
# a year ago DATE
# 79 CARDINAL
# night TIME
# one CARDINAL
# one CARDINAL
# night TIME
# 80 CARDINAL
# second ORDINAL
# 81 CARDINAL
# Ah! WORK_OF_ART
# one CARDINAL
# five hundred million MONEY
# five hundred million CARDINAL
# 82 CARDINAL
# You know-- WORK_OF_ART
# four CARDINAL
# one CARDINAL
# 83 CARDINAL
# 84 CARDINAL
# Chapter 27 LAW
# six years DATE
# five hundred million MONEY
# one CARDINAL
# every night TIME
# some one evening TIME
# 85 CARDINAL
# Earth LOC
# some day DATE
# African NORP

# %%
filepath = r"C:\Users\qnj\Desktop\NLP\Little Prince.txt"
text = open(filepath, encoding='utf-8').read()

# %%
import math
number_of_chunks = 80

chunk_size = math.ceil(len(text) / number_of_chunks)

text_chunks = []

for number in range(0, len(text), chunk_size):
    text_chunk = text[number:number+chunk_size]
    text_chunks.append(text_chunk)

chunked_documents = list(nlp.pipe(text_chunks))

# %%
people = []

for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "PERSON":
            people.append(named_entity.text)

people_tally = Counter(people)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
print(df)
# Out:
#         character  count
# 0  Asteroid B-612      2
# 1         sheep--      2
# 2             Boa      1
# 3         doubt--      1
# 4            Yawn      1
# 5            Bees      1

# %%
places = []
for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "GPE" or named_entity.label_ == "LOC":
            places.append(named_entity.text)

places_tally = Counter(places)

df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
print(df)
# Out:
#                    place  count
# 0                  Earth     17
# 1                    Hum      8
# 2                 France      3
# 3                  China      2
# 4                  earth      2
# 5                 Africa      2
# 6          South America      2
# 7                 Sahara      2
# 8                Arizona      1
# 9   the Desert of Sahara      1
# 10               Jupiter      1
# 11                  Mars      1
# 12     the United States      1
# 13           New Zealand      1
# 14             Australia      1
# 15               Siberia      1
# 16                Russia      1
# 17                Europe      1
# 18         North America      1
# 19        the North Pole      1
# 20                 South      1
# 21               Pacific      1
# 22             vineyards      1
